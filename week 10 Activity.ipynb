# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 1-Read Data into python

# %%
df=pd.read_csv('week10.csv')

# %%
df.head()
# Out:
#           ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0   8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 1   9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
# 2   5.584087  188.313324  28748.68774     7.544869  326.678363    280.467916
# 3  10.223862  248.071735  28749.71654     7.513408  393.663395    283.651634
# 4   8.635849  203.361523  13672.09176     4.563009  303.309771    474.607645
#
#    Organic_carbon  Trihalomethanes  Turbidity
# 0       18.436525       100.341674   4.628771
# 1       11.558279        31.997993   4.075075
# 2        8.399735        54.917862   2.559708
# 3       13.789695        84.603556   2.672989
# 4       12.363817        62.798309   4.401425

# %%
df.tail()
# Out:
#              ph    Hardness       Solids  Chloramines     Sulfate  \
# 2006   8.989900  215.047358  15921.41202     6.297312  312.931021
# 2007   6.702547  207.321086  17246.92035     7.708117  304.510230
# 2008  11.491011   94.812545  37188.82602     9.263166  258.930600
# 2009   6.069616  186.659040  26138.78019     7.747547  345.700257
# 2010   4.668102  193.681736  47580.99160     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 2006    390.410231        9.899115        55.069304   4.613843
# 2007    329.266002       16.217303        28.878601   3.442983
# 2008    439.893618       16.172755        41.558501   4.369264
# 2009    415.886955       12.067620        60.419921   3.669712
# 2010    526.424171       13.894419        66.687695   4.435821

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2011 non-null   float64
#  1   Hardness         2011 non-null   float64
#  2   Solids           2011 non-null   float64
#  3   Chloramines      2011 non-null   float64
#  4   Sulfate          2011 non-null   float64
#  5   Conductivity     2011 non-null   float64
#  6   Organic_carbon   2011 non-null   float64
#  7   Trihalomethanes  2011 non-null   float64
#  8   Turbidity        2011 non-null   float64
# dtypes: float64(9)
# memory usage: 141.5 KB

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2011.000000  2011.000000   2011.000000  2011.000000  2011.000000
# mean      7.085990   195.968072  21917.441375     7.134338   333.224672
# std       1.573337    32.635085   8642.239815     1.584820    41.205172
# min       0.227499    73.492234    320.942611     1.390871   129.000000
# 25%       6.089723   176.744938  15615.665390     6.138895   307.632511
# 50%       7.027297   197.191839  20933.512750     7.143907   332.232177
# 75%       8.052969   216.441070  27182.587065     8.109726   359.330555
# max      14.000000   317.338124  56488.672410    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity
# count   2011.000000     2011.000000      2011.000000  2011.000000
# mean     426.526409       14.357709        66.400859     3.969729
# std       80.712572        3.324959        16.077109     0.780346
# ...

# %% [markdown]
# ### 2-Check for null Values

# %%
df.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# dtype: int64

# %% [markdown]
# There is no null values

# %% [markdown]
# ### 3-Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and comment on your observations.

# %%
plt.boxplot(df[['Sulfate','Hardness','Organic_carbon']]);

# %%
variables = ['Hardness','Sulfate', 'Organic_carbon']
sns.pairplot(df[variables]);

# %%
sns.pairplot(df[variables], kind="kde");

# %% [markdown]
# the variables contains outliers

# %% [markdown]
# ### 4-Carry out correlation analysis on the dataset and find the correlation factor between

# %% [markdown]
# Correlation analysis on dataset

# %%
corrmatrix=df.corr()
plt.subplots(figsize=(20,20))
sns.heatmap(corrmatrix,vmin=.2,vmax=1,annot=True,linewidth=.2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# correlation between ph and chloramines

# %%
df1=df[['ph','Chloramines']]
corrmatrix1=df1.corr()
plt.subplots(figsize=(8,8))
sns.heatmap(corrmatrix1,vmin=.2,vmax=1,annot=True,linewidth=.2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the analysis we got -0.25 as the result.which is very low. we can conclude that there is no correlation between ph and Chloramines.

# %% [markdown]
# Correlation between ph and conductivity

# %%
df2=df[['ph','Conductivity']]
corrmatrix2=df2.corr()
plt.subplots(figsize=(10,8))
sns.heatmap(corrmatrix2,vmin=.2,vmax=1,annot=True,linewidth=.2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the analysis we got 0.14 as the result.which is very low to consider. we can conclude that there is no correlation between ph and conductivity.
